# %%
from raster import Raster

from gui import GUI

# %%
image_f = 'fire_C11659/S2C_MSIL2A_20251007T193321_N0511_R142_T09UYU_20251007T222118_cloudfree.bin_MRAP_C11659.bin'
polygon_f = 'polygon_C11659/polygon_0000.bin'

# %%
g = GUI(
    polygon_filename=polygon_f,
    image_filename=image_f
)
# Out:
# [1, 4]: pid = 33816 running...
# [1, 3]: pid = 33815 running...[1, 2]: pid = 33814 running...
#
# [2, 3]: pid = 33817 running...
# [1, 2]: pid = 33814 ...Done.
# [2, 4]: pid = 33814 running...
# [2, 3]: pid = 33817 ...Done.
# [3, 4]: pid = 33817 running...
# [1, 3]: pid = 33815 ...Done.
# [1, 4]: pid = 33816 ...Done.
# [1, 2, 3]: pid = 33815 running...
# [1, 2, 4]: pid = 33816 running...
# [3, 4]: pid = 33817 ...Done.
# [1, 3, 4]: pid = 33817 running...
# [2, 4]: pid = 33814 ...Done.
# [2, 3, 4]: pid = 33814 running...
# [1, 2, 4]: pid = 33816 ...Done.
# [1, 2, 3, 4]: pid = 33816 running...
# [1, 2, 3]: pid = 33815 ...Done.
# [2, 3, 4]: pid = 33814 ...Done.
# [1, 3, 4]: pid = 33817 ...Done.
# [1, 2, 3, 4]: pid = 33816 ...Done.
# OpenTSNE on 11 data took 8.82 s
# Saving Embedding...

# %%
g.band_list = [1,2,3]

# %%
g.get_band_embed()
# Out:
# array([[-0.38028549, -1.78301632],
#        [-0.22302573, -1.43537313],
#        [-0.14379599,  0.8673146 ],
#        ...,
#        [ 0.47443321, -0.95267869],
#        [ 0.16679802, -1.43692296],
#        [ 0.37258336,  0.16685575]], shape=(1118, 2))

# %%
g.current_embedding.transform(
    g.image_dat[..., [0,1,2]].reshape(-1, len(g.band_list))[:40000]
)
# Out:
# PartialTSNEEmbedding([[ 0.67543587, -1.14010723],
#                       [ 0.65531634, -1.25966097],
#                       [ 0.61724968, -1.34310303],
#                       ...,
#                       [-0.28099327,  0.54127529],
#                       [-0.29162174,  0.56444587],
#                       [-0.30312628,  0.59022772]], shape=(40000, 2))
