# %%
#Do this to work on main dir
import os
os.chdir("/home/bill/GitHub/wps-research/data/bill")

# %%
import importlib
from pathlib import Path

# %%
from SAFE import (
    extract_L1,
    extract_L2,
    extract_and_resample_L1
)

from raster import Raster

# %% [markdown]
# Extract bands

# %%
# safe_dir = 'C11659/L1C/S2B_MSIL1C_20250919T191959_N0511_R099_T09UYU_20250919T223539.SAFE'

# ENVI_band_stack_L1(
#     safe_dir=safe_dir,
#     band_list=['B12','B11','B8A'],
#     out_dir=Path('C11659/L1C/extracted')
# )

# %%
# safe_dir = 'C11659/L2A/S2B_MSIL2A_20250902T192909_N0511_R142_T09UYU_20250902T231719.SAFE'

# extract_L2(
#     safe_dir=safe_dir,
#     band_list='all',
#     resolution=60,
#     out_dir=Path('C11659/L2A/Extracted')
# )

# %%
# #Resample L1

# safe_dir = 'C11659/L1C/S2B_MSIL1C_20250919T191959_N0511_R099_T09UYU_20250919T223539.SAFE'


# extract_and_resample_L1(
#     safe_dir = safe_dir,
#     target_resolution=60,
#     out_dir = Path('C11659/L1C/resampled')
# )
# Out:
# PosixPath('C11659/L1C/resampled/S2B_MSIL1C_20250919T191959_N0511_R099_T09UYU_20250919T223539_60m.bin')

# %%
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

root_dir = Path("C11659/L1C")
out_dir = Path("C11659/L1C/resampled")
out_dir.mkdir(parents=True, exist_ok=True)

safe_dirs = list(root_dir.glob("*.SAFE"))

def process_safe(safe_dir):
    print(f"Processing {safe_dir.name}")
    
    extract_and_resample_L1(
        safe_dir=safe_dir,
        band_list=['B12', 'B11', 'B09', 'B08'],
        target_resolution=20,
        out_dir=out_dir
    )
    return safe_dir.name


# Adjust max_workers depending on CPU & disk
with ThreadPoolExecutor(max_workers=4) as executor:
    futures = [executor.submit(process_safe, d) for d in safe_dirs]

    for future in as_completed(futures):
        try:
            result = future.result()
            print(f"Finished {result}")
        except Exception as e:
            print("Error:", e)

# %% [markdown]
# Extract Cloud (iteratively from a folder of zip)

# %%
# import zipfile
# import shutil

# %%
# ZIP_ROOT = Path("/data/bill/mrap/Level2")

# RES = 20

# OUT_DIR = Path(paths['l2a_dir']) / f'cloud_{RES}m'

# OUT_DIR

# %%
# ENVI_cloud_L2_from_zip_root(
#     zip_root="/data/bill/mrap/Level2",
#     resolution=60,
#     out_root=paths['l2a_dir']
# )

# %%
# ENVI_cloud_L2(
#     safe_dir=safe_dir,
#     resolution=60,
#     out_dir=OUT_DIR
# )

# %% [markdown]
# PNG Cloud

# %%
# import imageio.v2 as imageio
# import numpy as np

# %%
# envi_dir = Path("C11659/L2A/cloud_60m")
# out_dir  = Path("C11659/L2A/cloud_60m")

# out_dir.mkdir(parents=True, exist_ok=True)

# bin_files = sorted(envi_dir.glob("*.bin"))

# for bin_file in bin_files:
#     data = Raster(bin_file).read_bands()

#     band = data[..., 0]

#     png = normalize_uint8(band)

#     out_path = out_dir / f"{bin_file.stem}.png"

#     imageio.imwrite(out_path, png)

#     print(f"Saved {out_path.name}")
