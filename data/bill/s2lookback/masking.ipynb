# %%
import os

os.chdir('/home/bill/GitHub/wps-research/data/bill')

# %%
from mask import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from mask import *
#
# File ~/GitHub/wps-research/data/bill/s2lookback/mask.py:7
#       1 '''
#       2 A look back method.
#       3
#       4 This module attempts to mask cloud, cloud shadow.
#       5 '''
# ----> 7 from s2lookback.base import LookBack
#       9 import os
#      11 import joblib
#
# ModuleNotFoundError: No module named 's2lookback'

# %%
masker = MASK(
        image_dir='C11659/L1C/resampled_20m',
        mask_dir='C11659/cloud_20m',
        output_dir='C11659/wps_cloud/cloud_2'
    )

masker.fit()
# Out:
# Iterating completed | omitted 6 mask files.
# Dictionary completed | it stores 86 timestamps.
# ----------------------------------------------------------------------------------------------------
#
# 1. Processing 2025-05-02 19:19:09 ...
#
# ***
#  > Sampling Data: 2025-05-02 19:19:09
#   + 50000 samples of mask | Label = 1 | Total 50000
#   + 50000 samples of non_mask | Label = 0 | Total 50000
#
# ~~~
#  > Fitting classifier on 90000 data.
#
# ~~~
#  > Evaluating model...
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      5004
#            1       0.94      0.89      0.91      4996
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000
#
#
# +++
#  < Model Saved @ C11659/wps_cloud/cloud_2/models/2025-05-02 19:19:09.joblib.
# ...
