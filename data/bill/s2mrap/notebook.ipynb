# %%
import os

os.chdir('/home/bill/GitHub/wps-research/data/bill')

# %%
from raster import Raster

# %%
file = 'C11659/L1C/extracted/S2A_MSIL1C_20250830T193831_N0511_R142_T09UYU_20250831T003315.bin'

# %%
a = Raster(file)

# %%
a.meta['acquisition_time']
# Out:
# '2025-08-30T19:38:31.024Z'

# %%
from datetime import datetime
datetime.fromisoformat("2025-08-30T19:38:31.024Z")
# Out:
# datetime.datetime(2025, 8, 30, 19, 38, 31, 24000, tzinfo=datetime.timezone.utc)
