# %%
import os

os.chdir('/home/bill/GitHub/wps-research/data/bill')

# %%
import raster
import numpy as np
from plot_tools import plot
from misc import htrim_3d

# %%
import importlib

importlib.reload(raster)
# Out:
# <module 'raster' from '/home/bill/GitHub/wps-research/data/bill/raster.py'>

# %%
a = [1,2,3]

# %%
a[:2][::-1]
# Out:
# [2, 1]

# %%
from raster import Raster

# %%
file = 'C11659/L1C/extracted/S2B_MSIL1C_20250909T191909_N0511_R099_T09UYU_20250909T225427.bin'

# %%
a = Raster(file)

# %%
img = Raster(file)

# %%
dat = img.read_bands()

# %%
from photos import save_png_same_dir

# %%
save_png_same_dir(
    'C11659/L1C/extracted'
)
# Out:
# Saved C11659/L1C/extracted/S2B_MSIL1C_20250919T191959_N0511_R099_T09UYU_20250919T223539.png
# Saved C11659/L1C/extracted/S2A_MSIL1C_20250830T193831_N0511_R142_T09UYU_20250831T003315.png
# Saved C11659/L1C/extracted/S2B_MSIL1C_20250902T192909_N0511_R142_T09UYU_20250902T230923.png
# Saved C11659/L1C/extracted/S2B_MSIL1C_20250909T191909_N0511_R099_T09UYU_20250909T225427.png
